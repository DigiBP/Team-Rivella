# %% [markdown]
# # Get token / to identify yourself

# %%
import requests
import pandas as pd
import json


url = 'https://c719ecc6-7add-42e5-96f8-239e9c0d87b1.deepnoteproject.com/login'

#login data
user = 'user5'
password = 'zaCno46u'


# Data to be sent in the POST request (in this case, a dictionary)
data = {'user': user, 'password': password}

# Sending a POST request with requests.post()
response = requests.post(url, data=data)

# Checking the response
if response.status_code == 200:
    print("POST request was successful!")
    print("Response:", response.text)

else:
    print("POST request failed. Status code:", response.status_code)

resp_dict = json.loads(response.text)
token = resp_dict['access_token']
# Out:
# POST request was successful!
# Response: {"access_token":"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJmcmVzaCI6ZmFsc2UsImlhdCI6MTcwMDQ5Mzk5OSwianRpIjoiOTE4YWVkOWItZTZlYy00ZDczLThjNjAtZTA0MGJhZjNhZjQ0IiwidHlwZSI6ImFjY2VzcyIsInN1YiI6InVzZXI1IiwibmJmIjoxNzAwNDkzOTk5LCJleHAiOjE3MDA0OTQ4OTl9.ZiusONDmGRmgACgaQxZB7XPH078wkEdaUwfzammu4RI","message":"Login Successful"}

# %% [markdown]
# # Fetch patient information

# %%
import requests
import pandas as pd



def fetch_patient_information(api_url, headers=None):
    try:
        response = requests.get(api_url, headers=headers)

        if response.status_code == 200:  # Assuming 200 indicates a successful request
            patient_data = response.json()
            return patient_data
        else:
            print(f"Failed to fetch data. Status code: {response.status_code}")
            return None
    
    except requests.RequestException as e:
        print(f"Request Exception: {e}")
        return None


# Example API endpoint URL
api_endpoint = 'https://c719ecc6-7add-42e5-96f8-239e9c0d87b1.deepnoteproject.com/patient_data'
# If the API requires authentication, provide necessary headers (such as API key, token, etc.)
api_headers = {'Authorization': 'Bearer '+ token}



# Fetch patient information
patient_info = fetch_patient_information(api_endpoint, headers=api_headers)

if patient_info:
    # Process or display patient information
    print(patient_info)
    # You can iterate through patient_info and access specific fields as needed
else:
    print("Failed to fetch patient information.")
# Out:
# {'bp_val': 90, 'chol_val': 60, 'doctor': 'Man Steiner', 'patient_fname': 'max', 'patient_id': 1}

# %% [markdown]
# # Fetch lab data

# %%
# Example API endpoint URL
api_endpoint = 'https://c719ecc6-7add-42e5-96f8-239e9c0d87b1.deepnoteproject.com/lab_data'

# If the API requires authentication, provide necessary headers (such as API key, token, etc.)
api_headers = {'Authorization': 'Bearer '+ token}


# Fetch lab data
patient_info = fetch_patient_information(api_endpoint, headers=api_headers)

if patient_info:
    # Process or display patient information
    print(patient_info)
    # You can iterate through patient_info and access specific fields as needed
else:
    print("Failed to fetch patient information.")
# Out:
# [{"patient_id":11,"date":1641340800000,"CBC":9.42,"BMP":83.05,"CMP":74.1,"Lipid Panel":136.81,"TFTs":2.69,"Urinalysis":1.23,"LFTs":19.01,"Electrolyte Panel":143.51,"Coagulation Panel":10.29,"Blood Glucose":84.69},{"patient_id":11,"date":1641686400000,"CBC":5.31,"BMP":null,"CMP":59.29,"Lipid Panel":263.29,"TFTs":4.41,"Urinalysis":1.89,"LFTs":null,"Electrolyte Panel":null,"Coagulation Panel":null,"Blood Glucose":100.27},{"patient_id":11,"date":1642464000000,"CBC":4.47,"BMP":85.99,"CMP":70.89,"Lipid Panel":null,"TFTs":2.28,"Urinalysis":1.6,"LFTs":40.15,"Electrolyte Panel":144.19,"Coagulation Panel":12.45,"Blood Glucose":119.54},{"patient_id":11,"date":1646784000000,"CBC":null,"BMP":98.58,"CMP":91.45,"Lipid Panel":null,"TFTs":2.42,"Urinalysis":1.16,"LFTs":38.4,"Electrolyte Panel":138.82,"Coagulation Panel":13.82,"Blood Glucose":84.76},{"patient_id":11,"date":1647129600000,"CBC":9.82,"BMP":85.29,"CMP":10.07,"Lipid Panel":120.84,"TFTs":null,"Urinalysis":1.73,"LFTs":27.63,"Electrolyte Panel":136.43,"Coagulation Panel":13.87,"Blood Glucose":108.26},{"patient_id":11,"date":1647388800000,"CBC":null,"BMP":85.76,"CMP":53.19,"Lipid Panel":150.4,"TFTs":0.57,"Urinalysis":1.73,"LFTs":36.08,"Electrolyte Panel":139.61,"Coagulation Panel":13.69,"Blood Glucose":null},{"patient_id":11,"date":1652659200000,"CBC":6.12,"BMP":83.67,"CMP":39.7,"Lipid Panel":171.14,"TFTs":1.24,"Urinalysis":0.65,"LFTs":5.29,"Electrolyte Panel":137.64,"Coagulation Panel":13.8,"Blood Glucose":117.02},{"patient_id":11,"date":1668038400000,"CBC":null,"BMP":90.89,"CMP":92.68,"Lipid Panel":252.2,"TFTs":1.53,"Urinalysis":1.56,"LFTs":19.38,"Electrolyte Panel":null,"Coagulation Panel":14.1,"Blood Glucose":90.3}]

# %% [markdown]
# # Check as which user you're logged in

# %%
#GET HOME message / which user your logged in with

# Example API endpoint URL
url = 'https://c719ecc6-7add-42e5-96f8-239e9c0d87b1.deepnoteproject.com/'

# If the API requires authentication, provide necessary headers (such as API key, token, etc.)
api_headers = {'Authorization': 'Bearer '+ token}


response = requests.get(url, headers=api_headers)



# Checking the response
if response.status_code == 200:
    print("GET request was successful!")
    print("Response:", response.text)

else:
    print("GET request failed. Status code:", response.status_code)
# Out:
# GET request was successful!
# Response: Welcome to EHR database, you're logged in as: user5

# %% [markdown]
# # Transform JSON to dataframe

# %%
import pandas as pd

df = pd.read_json(patient_info)
# Out:
#    patient_id       date   CBC    BMP    CMP  Lipid Panel  TFTs  Urinalysis  \
# 0          11 2022-01-05  9.42  83.05  74.10       136.81  2.69        1.23
# 1          11 2022-01-09  5.31    NaN  59.29       263.29  4.41        1.89
# 2          11 2022-01-18  4.47  85.99  70.89          NaN  2.28        1.60
# 3          11 2022-03-09   NaN  98.58  91.45          NaN  2.42        1.16
# 4          11 2022-03-13  9.82  85.29  10.07       120.84   NaN        1.73
# 5          11 2022-03-16   NaN  85.76  53.19       150.40  0.57        1.73
# 6          11 2022-05-16  6.12  83.67  39.70       171.14  1.24        0.65
# 7          11 2022-11-10   NaN  90.89  92.68       252.20  1.53        1.56
#
#     LFTs  Electrolyte Panel  Coagulation Panel  Blood Glucose
# 0  19.01             143.51              10.29          84.69
# 1    NaN                NaN                NaN         100.27
# 2  40.15             144.19              12.45         119.54
# 3  38.40             138.82              13.82          84.76
# 4  27.63             136.43              13.87         108.26
# 5  36.08             139.61              13.69            NaN
# 6   5.29             137.64              13.80         117.02
# 7  19.38                NaN              14.10          90.30

# %%
import pandas as pd

df = pd.read_json(patient_info)

last_values = {}
for col in df.columns:
    if col == 'date':
        continue
    last_valid_idx = df[col].last_valid_index()
    last_values[col] = df.loc[last_valid_idx, col] if last_valid_idx else None

print("Last non-NA values in each column:")

last_values = pd.DataFrame([last_values])


print('Last valid values: ', last_values)
last_values
# Out:
# Last non-NA values in each column:
# Last valid values:     patient_id   CBC    BMP    CMP  Lipid Panel  TFTs  Urinalysis   LFTs  \
# 0          11  6.12  90.89  92.68        252.2  1.53        1.56  19.38
#
#    Electrolyte Panel  Coagulation Panel  Blood Glucose
# 0             137.64               14.1           90.3
#    patient_id   CBC    BMP    CMP  Lipid Panel  TFTs  Urinalysis   LFTs  \
# 0          11  6.12  90.89  92.68        252.2  1.53        1.56  19.38
#
#    Electrolyte Panel  Coagulation Panel  Blood Glucose
# 0             137.64               14.1           90.3

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c719ecc6-7add-42e5-96f8-239e9c0d87b1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
